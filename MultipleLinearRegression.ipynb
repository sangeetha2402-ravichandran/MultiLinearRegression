# %% [markdown]
# PROBLEM STATEMENT
#
# This dataset is created for prediction of S&P500 stock index based on interest rate and employment numbers

# %% [markdown]
# STEP 1 IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# STEP 2 IMPORT DATASET

# %%
stock = pd.read_csv("S&P500_Stock_Data.csv")

# %%
stock
# Out:
#      Interest Rates  Employment  S&P 500 Price
# 0          1.943859   55.413571    2206.680582
# 1          2.258229   59.546305    2486.474488
# 2          2.215863   57.414687    2405.868337
# 3          1.977960   49.908353    2140.434475
# 4          2.437723   52.035492    2411.275663
# ..              ...         ...            ...
# 995        2.528420   52.390828    2578.699184
# 996        2.643571   54.626204    2573.865933
# 997        2.009644   57.004357    2004.911218
# 998        2.201656   62.447790    2344.098981
# 999        2.180638   46.297034    2156.133786
#
# [1000 rows x 3 columns]

# %%
stock.head(10)
# Out:
#    Interest Rates  Employment  S&P 500 Price
# 0        1.943859   55.413571    2206.680582
# 1        2.258229   59.546305    2486.474488
# 2        2.215863   57.414687    2405.868337
# 3        1.977960   49.908353    2140.434475
# 4        2.437723   52.035492    2411.275663
# 5        2.143637   56.060598    2187.344909
# 6        2.148647   51.513208    2263.049249
# 7        2.176184   53.475909    2281.496374
# 8        2.125352   63.668422    2355.163011
# 9        2.225682   56.993396    2326.330337

# %%
stock.tail(10)
# Out:
#      Interest Rates  Employment  S&P 500 Price
# 990        2.018200   56.929616    2206.946180
# 991        1.936748   52.967524    2086.159182
# 992        2.591529   57.281030    2686.211789
# 993        1.740441   55.098645    1922.893274
# 994        1.868835   60.543377    2065.424594
# 995        2.528420   52.390828    2578.699184
# 996        2.643571   54.626204    2573.865933
# 997        2.009644   57.004357    2004.911218
# 998        2.201656   62.447790    2344.098981
# 999        2.180638   46.297034    2156.133786

# %%
stock.describe()
# Out:
#        Interest Rates   Employment  S&P 500 Price
# count     1000.000000  1000.000000    1000.000000
# mean         2.195392    56.254855    2319.999936
# std          0.241630     4.862178     193.854745
# min          1.500000    40.000000    1800.000000
# 25%          2.035735    53.029784    2190.447901
# 50%          2.198214    56.160941    2312.443024
# 75%          2.359061    59.422633    2455.764328
# max          3.000000    70.000000    3000.000000

# %% [markdown]
# stock.info()

# %% [markdown]
# STEP3 VISUALIZE DATA SET

# %%
sns.jointplot(x= 'Employment', y= 'S&P 500 Price', data= stock)

# %%
sns.jointplot(x= 'Interest Rates', y= 'S&P 500 Price', data= stock)

# %%
sns.pairplot(stock)

# %%
sns.lmplot(x= 'Employment', y= 'S&P 500 Price', data= stock)

# %%
sns.lmplot(x= 'Interest Rates', y= 'S&P 500 Price', data= stock)

# %% [markdown]
# STEP 4 CREATE TRAINING AND TESTING DATA

# %%
y = stock['S&P 500 Price']

# %%
X = stock[['Interest Rates', 'Employment']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#      Interest Rates  Employment
# 692        2.368177   45.292347
# 498        2.500402   54.094836
# 447        2.127391   63.093375
# 616        2.297676   47.252752
# 68         2.294610   50.273559
# ..              ...         ...
# 293        2.128800   55.186073
# 634        2.015127   50.597614
# 235        2.003230   55.833489
# 827        2.317105   53.117706
# 348        2.313274   56.597454
#
# [800 rows x 2 columns]

# %%
y_train
# Out:
# 692    2321.947646
# 498    2608.523191
# 447    2330.839703
# 616    2298.132355
# 68     2226.020117
#           ...
# 293    2331.293250
# 634    2114.861602
# 235    2240.762386
# 827    2418.146203
# 348    2404.232249
# Name: S&P 500 Price, Length: 800, dtype: float64

# %%
y_test.shape
# Out:
# (200,)

# %%
X_train.shape
# Out:
# (800, 2)

# %%
X_test.shape
# Out:
# (200, 2)

# %% [markdown]
# STEP 5 TRAIN MODEL

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression(fit_intercept = True) # False then  b is 0
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear regression coefficient m- slope', regression.coef_)
print('Linear regression coefficient b - intercept', regression.intercept_)
# Out:
# Linear regression coefficient m- slope [734.38113455  12.56297418]
# Linear regression coefficient b - intercept 0.0

# %% [markdown]
# STEP 6 EVALUATE THE MODEL

# %%
y_predict = regression.predict(X_test)

# %%
y_predict
# Out:
# array([2470.87269172, 2605.93784129, 2440.96404411, 2390.78872871,
#        2155.95076258, 2381.77506153, 2548.96015236, 2109.04091886,
#        2323.38801455, 2213.10008098, 2278.35221931, 1971.96371954,
#        2303.33261366, 2367.66481296, 2578.81534735, 2317.01823951,
#        2146.68588152, 2488.00702006, 2257.56580012, 2192.38206966,
#        2401.02477025, 2473.5104051 , 2722.02247499, 2336.32604035,
#        2196.94556572, 2075.9425345 , 2327.73958123, 2092.69873448,
#        2474.37091753, 2219.79155457, 2513.29689281, 2336.20219163,
#        2400.75382946, 2219.48912624, 2627.32571892, 2249.53302471,
#        1990.61320425, 2132.16687444, 1928.48457674, 2235.22531256,
#        2224.508686  , 2509.5635737 , 1984.67554246, 2096.89993213,
#        2057.14424531, 2165.74016588, 2361.62737525, 2276.0865678 ,
#        2153.20700751, 2204.16793944, 2545.49841569, 2564.70433843,
#        2100.28650757, 2361.11210592, 2148.98587385, 2343.84637678,
# ...

# %%
y_test
# Out:
# 933    2493.524016
# 795    2572.590836
# 312    2411.861322
# 150    2440.409300
# 924    2132.422606
#           ...
# 480    2213.870263
# 968    2492.335968
# 850    2309.746169
# 272    2129.542585
# 576    2301.311080
# Name: S&P 500 Price, Length: 200, dtype: float64

# %%
plt.scatter(y_predict, y_test, color = 'gray')
plt.ylabel("Model prediction")
plt.xlabel("True Values")
plt.title("MultiLinearRegression")
# Out:
# Text(0.5, 1.0, 'MultiLinearRegression')

# %%
k=X_test.shape
n=len(X_test)

# %%
k
# Out:
# (200, 2)

# %%
n
# Out:
# 200

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from math import sqrt
RMSE = float(format(np.sqrt(mean_squared_error(y_test,y_predict)),'.3f')) # root mean square
MSE= mean_squared_error(y_test,y_predict) # mean square error
MAE= mean_absolute_error(y_test,y_predict) # mean aboslute error
r2 = r2_score(y_test,y_predict) # r square
NPSS = np.mean(np.abs((y_test - y_predict) / y_test) ) * 100 # mean absolute percentage of error
print('RMSE=', RMSE, '\nMSE=' , MSE , '\nMAE=' , MAE , '\nr2=',  r2 ,'\nNPS=' , NPS)
# Out:
# RMSE= 58.441
# MSE= 3415.3034101179614
# MAE= 48.21895872281902
# r2= 0.9011510355729248
# NPS= 2.0962970425354674

# %% [markdown]
# STEP 6 VISUALIZE THE RESULTS

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x_surf , y_surf = np.meshgrid( np.linspace( stock['Interest Rates'].min(),stock['Interest Rates'].max(), 100), np.linspace( stock['Employment'].min(), stock['Employment'].max(), 100))

# %%
x_surf.shape
# Out:
# (100, 100)

# %%
onlyX = pd.DataFrame( {'Interest Rates': x_surf.ravel() , 'Employment': y_surf.ravel()})

# %%
onlyX.shape
# Out:
# (10000, 2)

# %%
fittedY = regression.predict(onlyX)
fittedY
# Out:
# array([1619.71608269, 1630.70984553, 1641.70360837, ..., 3045.95308836,
#        3056.94685119, 3067.94061403])

# %%
fittedY = fittedY.reshape(x_surf.shape)
fittedY
# Out:
# array([[1619.71608269, 1630.70984553, 1641.70360837, ..., 2686.11107794,
#         2697.10484078, 2708.09860362],
#        [1623.35085047, 1634.34461331, 1645.33837615, ..., 2689.74584572,
#         2700.73960856, 2711.7333714 ],
#        [1626.98561825, 1637.97938109, 1648.97314393, ..., 2693.38061351,
#         2704.37437634, 2715.36813918],
#        ...,
#        [1972.28855754, 1983.28232038, 1994.27608322, ..., 3038.68355279,
#         3049.67731563, 3060.67107847],
#        [1975.92332532, 1986.91708816, 1997.910851  , ..., 3042.31832057,
#         3053.31208341, 3064.30584625],
#        [1979.55809311, 1990.55185594, 2001.54561878, ..., 3045.95308836,
#         3056.94685119, 3067.94061403]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111 , projection = '3d')
ax.scatter(stock['Interest Rates'], stock['Employment'], stock['S&P 500 Price'], color='blue', marker ='x' )
ax.plot_surface(x_surf, y_surf, fittedY, color='red', alpha = 0.3)
ax.set_xlabel("Interest Rates")
ax.set_ylabel("Unemployment Rates")
ax.set_ylabel("Stock Index Rates")
# Out:
# Text(0.5, 0.5, 'Stock Index Rates')

# %%
fig = plt.figure()
ax = fig.add_subplot(111 , projection = '3d')
ax.scatter(stock['Interest Rates'], stock['Employment'], stock['S&P 500 Price'], color='blue', marker ='x' )
ax.plot_surface(x_surf, y_surf, fittedY, color='red', alpha = 0.3)
ax.set_xlabel("Interest Rates")
ax.set_ylabel("Unemployment Rates")
ax.set_ylabel("Stock Index Rates")
ax.view_init(0,30)
plt.show()

# %%
coeff_df = pd.DataFrame(regression.coef_ , X.columns, columns = ['Coefficient'])
coeff_df
# Out:
#                 Coefficient
# Interest Rates   725.588347
# Employment        11.994734
